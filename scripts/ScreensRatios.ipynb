# %%
# @title  Screens Ratios

import matplotlib.pyplot as plt
from   matplotlib.patches import Rectangle
import numpy as np

# %matplotlib inline
def plot_rectangle(data,ax,display_horizontal=True):

    r,n,d = data['ratio'],data['name'],data['size']*2.54
    h = np.sqrt(d**2/(1+r**2))
    w = h*r
    if display_horizontal:
       t = f'{n:7s}  W:{w:0.2f}  H:{h:0.2f}  W*H:{w*h:0.2f}'
       print(t)
       ax[0].add_patch( Rectangle((0,0),       w, h, fill=False, label=t, color=data['color']) )
       ax[1].add_patch( Rectangle((-w/2,-h/2), w, h, fill=False, label=t, color=data['color']) )
    else:
       t = f'{n:7s}  W:{h:0.2f}  H:{w:0.2f}  W*H:{w*h:0.2f}'
       print(t)
       ax[0].add_patch( Rectangle((0,0),       h, w, fill=False, label=t, color=data['color']) )
       ax[1].add_patch( Rectangle((-h/2,-w/2), h, w, fill=False, label=t, color=data['color']) )

    ax[0].plot(np.nan,np.nan),ax[0].set_aspect(1)
    ax[1].plot(np.nan,np.nan),ax[1].set_aspect(1)
    ax[0].legend(loc='lower center');ax[0],ax[0].set_xlabel('cm'),ax[0].set_ylabel('cm');
    ax[1].legend(loc='center');ax[1],ax[1].set_xlabel('cm'),ax[0].set_ylabel('cm');

px2inch = 1/plt.rcParams['figure.dpi']
plt.rc('legend',fontsize = 16)

# %%
# @title  Screens H

DATA = [
        #{'size':18.0,'ratio':16/10,'name':'Razer18','color':'k'},
        #{'size':17.0,'ratio':16/10,'name':'LG17' ,'color':'r'},
        {'size':16.0,'ratio':16/10,'name':'Dell16','color':'b'},
        {'size':17.3,'ratio':16/9,'name':'MSI17' ,'color':'m'},
        {'size':15.6,'ratio':16/9,'name':'GELO' ,'color':'g'},
        {'size':17,'ratio':16/10,'name':'LG18' ,'color':'k'},
        {'size':18,'ratio':16/10,'name':'RAZER18' ,'color':'r'},
        ]

fig, ax = plt.subplots(1,2,figsize=(1800*px2inch , 1200*px2inch),constrained_layout=True)
for data in DATA:
  plot_rectangle(data,ax)
# Out:
# Dell16   W:34.46  H:21.54  W*H:742.30
# MSI17    W:38.30  H:21.54  W*H:825.07
# GELO     W:34.54  H:19.43  W*H:670.89
# LG18     W:36.62  H:22.89  W*H:837.98
# RAZER18  W:38.77  H:24.23  W*H:939.47

# %%
# @title  Screens H

DATA = [
        {'size':18,  'ratio':16/10,'name':'R17','color':'r'},
        {'size':17,  'ratio':16/10,'name':'L17','color':'c'},
        {'size':17.3,'ratio':16/9 ,'name':'M17','color':'b'},
        {'size':16.0,'ratio':16/10,'name':'Y16','color':'g'},
        ]

fig, ax = plt.subplots(1,2,figsize=(1800*px2inch , 1200*px2inch),constrained_layout=True)
for data in DATA:
  plot_rectangle(data,ax)
# Out:
# R17      W:38.77  H:24.23  W*H:939.47
# L17      W:36.62  H:22.89  W*H:837.98
# M17      W:38.30  H:21.54  W*H:825.07
# Y16      W:34.46  H:21.54  W*H:742.30

# %%
# @title  Screens V
DATA = [
        {'size':24,'ratio':1920/1080,'name':'24 16:90' ,'color':'m'},
        {'size':24,'ratio':1920/1200,'name':'24 16:10' ,'color':'b'},
        {'size':27,'ratio':16/9     ,'name':'27 16:90' ,'color':'r'},
        {'size':27,'ratio':16/10    ,'name':'27 16:10' ,'color':'g'}]

fig, ax = plt.subplots(1,2,figsize=(1800*px2inch , 1200*px2inch),constrained_layout=True)
for data in DATA:
    plot_rectangle(data,ax,display_horizontal=False)
# Out:
# 24 16:90  W:29.89  H:53.13  W*H:1587.90
# 24 16:10  W:32.31  H:51.69  W*H:1670.17
# 27 16:90  W:33.62  H:59.77  W*H:2009.68
# 27 16:10  W:36.35  H:58.16  W*H:2113.81

# %%
# @title  Screens H

DATA = [
        {'size':12.9,'ratio': 2732/2048,'name':'iPAD_A13','color':'b'},
        {'size':10.86,'ratio':2360/1640,'name':'iPAD_A11','color':'r'},
        {'size':10.2,'ratio': 2160/1620,'name':'iPAD_N','color':'b'},
        #{'size':16.2,'ratio':3456/2234,'name':'Mac16' ,'color':'c'},
        ]

fig, ax = plt.subplots(1,2,figsize=(1800*px2inch , 1200*px2inch),constrained_layout=True)
for data in DATA:
  plot_rectangle(data,ax,display_horizontal=False)
# Out:
# iPAD_A13  W:19.65  H:26.22  W*H:515.26
# iPAD_A11  W:15.74  H:22.65  W*H:356.57
# iPAD_N   W:15.54  H:20.73  W*H:322.19

# %%
DATA = [
        {'size':12.9,'ratio':2732/2048,'name':'iPAD_P','color':'r'},
        {'size':11.0,'ratio':2388/1668,'name':'iPAD_P','color':'r'},
        {'size':10.9,'ratio':2360/1640,'name':'iPAD_A','color':'g'},
        {'size':10.2,'ratio':2160/1620,'name':'iPAD_N','color':'b'},
        #{'size':16.2,'ratio':3456/2234,'name':'Mac16' ,'color':'c'},
        ]

fig, ax = plt.subplots(1,2,figsize=(1800*px2inch , 1200*px2inch),constrained_layout=True)
for data in DATA:
  plot_rectangle(data,ax,display_horizontal=True)
# Out:
# iPAD_P   W:26.22  H:19.65  W*H:515.26
# iPAD_P   W:22.91  H:16.00  W*H:366.47
# iPAD_A   W:22.74  H:15.80  W*H:359.20
# iPAD_N   W:20.73  H:15.54  W*H:322.19

# %%
# @title  Screens V

k=1
DATA = [{'size':17.3,'ratio':(16/9 )**1,'name':'17 16:90','color':'g'},
        {'size':24,  'ratio':(16/9 )**-1,'name':'24 16:90','color':'r'},
        {'size':24,  'ratio':(16/10 )**-1,'name':'24 16:90','color':'g'},
        {'size':24,  'ratio':(3/2 )**-1,'name':'24 16:90','color':'b'},
        {'size':27,  'ratio':(16/9 )**1,'name':'24 16:90','color':'m'},
        {'size':24,  'ratio':(16/9 )**1,'name':'24 16:90','color':'m'},
        {'size':32,  'ratio':(16/9)**k,'name':'32 16:10','color':'g'},
        {'size':28.2,'ratio':(3/2)**k,'name':'28 3/2','color':'b'},]

fig, ax = plt.subplots(1,2,figsize=(1800*px2inch , 1200*px2inch),constrained_layout=True)
for data in DATA:
    plot_rectangle(data,ax,display_horizontal=True)
# Out:
# 17 16:90  W:38.30  H:21.54  W*H:825.07
# 24 16:90  W:29.89  H:53.13  W*H:1587.90
# 24 16:90  W:32.31  H:51.69  W*H:1670.17
# 24 16:90  W:33.81  H:50.72  W*H:1715.13
# 24 16:90  W:59.77  H:33.62  W*H:2009.68
# 24 16:90  W:53.13  H:29.89  W*H:1587.90
# 32 16:10  W:70.84  H:39.85  W*H:2822.93
# 28 3/2   W:59.60  H:39.73  W*H:2367.96

# %%
# @title  Screens H
k = -1
DATA = [
        {'size':17,  'ratio':16/10,    'name':'L17','color':'c'},
        {'size':17.3,'ratio':16/9 ,    'name':'M17','color':'b'},
        {'size':16.00,'ratio':16/10,    'name':'Y16','color':'g'},
        {'size':13.60,'ratio' :(2560/1664)**k,'name':'M2','color':'r'},
        {'size':12.90,'ratio':(2732/2048)**k,'name':'iPAD_13','color':'k'},
        {'size':10.96,'ratio':(2360/1640)**k,'name':'iPAD_11','color':'y'},
        ]

fig, ax = plt.subplots(1,2,figsize=(1800*px2inch , 1200*px2inch),constrained_layout=True)
for data in DATA:
  plot_rectangle(data,ax)
# Out:
# L17      W:36.62  H:22.89  W*H:837.98
# M17      W:38.30  H:21.54  W*H:825.07
# Y16      W:34.46  H:21.54  W*H:742.30
# M2       W:18.83  H:28.96  W*H:545.26
# iPAD_13  W:19.65  H:26.22  W*H:515.26
# iPAD_11  W:15.89  H:22.86  W*H:363.17

# %%
# @title  Screens H
k = -1
DATA = [
        {'size':24,'ratio':16/9,    'name':'L24','color':'c'},
        {'size':27,'ratio':16/9 ,   'name':'M27','color':'b'},
        ]

fig, ax = plt.subplots(1,2,figsize=(1800*px2inch , 1200*px2inch),constrained_layout=True)
for data in DATA:
  plot_rectangle(data,ax)
# Out:
# L24      W:53.13  H:29.89  W*H:1587.90
# M27      W:59.77  H:33.62  W*H:2009.68

# %%
k=1
DATA = [{'size':17.3,'ratio':(16/9 )**1,'name':'17 16:9 Genio','color':'g'},
        {'size':15.6,'ratio':(16/9 )**1,'name':'15 16:9 PJ','color':'g'},
        {'size':24,  'ratio':(16/9 )**1,'name':'24 16:90','color':'r'},
        {'size':24,  'ratio':(16/9 )**-1,'name':'24 16:90','color':'r'},
        {'size':32,  'ratio':(16/9)**k  ,'name':'32 16:9','color':'k'},
        {'size':28.2,'ratio':(3/2)**k   ,'name':'28 3/2','color':'m'},
        {'size':28.2,'ratio':(3/2)**-1   ,'name':'28 3/2','color':'m'}]

fig, ax = plt.subplots(1,2,figsize=(1800*px2inch , 1200*px2inch),constrained_layout=True)
for data in DATA:
    plot_rectangle(data,ax,display_horizontal=True)
# Out:
# 17 16:9 Genio  W:38.30  H:21.54  W*H:825.07
# 15 16:9 PJ  W:34.54  H:19.43  W*H:670.89
# 24 16:90  W:53.13  H:29.89  W*H:1587.90
# 24 16:90  W:29.89  H:53.13  W*H:1587.90
# 32 16:9  W:70.84  H:39.85  W*H:2822.93
# 28 3/2   W:59.60  H:39.73  W*H:2367.96
# 28 3/2   W:39.73  H:59.60  W*H:2367.96
